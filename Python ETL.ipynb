# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - ETL

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this final part you will:
#
# *   Run the ETL process
# *   Extract bank and market cap data from the JSON file `bank_market_cap.json`
# *   Transform the market cap currency using the exchange rate data
# *   Load the transformed data into a seperate CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import glob
import pandas as pd
from pandas import json_normalize
from datetime import datetime

# %% [markdown]
# As the exchange rate fluctuates, we will download the same dataset to make marking simpler. This will be in the same format as the dataset you used in the last section

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_1.json
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_2.json
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/exchange_rates.csv
# Out:
# --2023-03-03 14:54:56--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_1.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2815 (2.7K) [application/json]
# Saving to: ‘bank_market_cap_1.json’
#
# bank_market_cap_1.j 100%[===================>]   2.75K  --.-KB/s    in 0s
#
# 2023-03-03 14:54:56 (83.7 MB/s) - ‘bank_market_cap_1.json’ saved [2815/2815]
#
# --2023-03-03 14:54:57--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Lab%20-%20Extract%20Transform%20Load/data/bank_market_cap_2.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1429 (1.4K) [application/json]
# Saving to: ‘bank_market_cap_2.json’
#
# bank_market_cap_2.j 100%[===================>]   1.40K  --.-KB/s    in 0s
#
# 2023-03-03 14:54:57 (34.2 MB/s) - ‘bank_market_cap_2.json’ saved [1429/1429]
#
# --2023-03-03 14:54:58--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/exchange_rates.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 590 [text/csv]
# Saving to: ‘exchange_rates.csv’
#
# exchange_rates.csv  100%[===================>]     590  --.-KB/s    in 0s
#
# 2023-03-03 14:54:58 (16.6 MB/s) - ‘exchange_rates.csv’ saved [590/590]

# %% [markdown]
# ## Extract

# %% [markdown]
# ### JSON Extract Function
#
# This function will extract JSON files.

# %%
def extract_from_json(file_to_process):
    dataframe = pd.read_json(file_to_process)
    return dataframe
df=extract_from_json('bank_market_cap_1.json')

# %% [markdown]
# ## Extract Function
#
# Define the extract function that finds JSON file `bank_market_cap_1.json` and calls the function created above to extract data from them. Store the data in a `pandas` dataframe. Use the following list for the columns.

# %%
columns=['Name','Market Cap (US$ Billion)']

# %%
def extract_from_json(file_to_process):
    dataframe = pd.read_json(file_to_process)
    return dataframe
df=extract_from_json('bank_market_cap_1.json')
df=pd.DataFrame(df,columns=['Name','Market Cap (US$ Billion)'])
pd.set_option('display.max_columns', None)
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_74d1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74d1f_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_74d1f_level0_col1" class="col_heading level0 col1" >Market Cap (US$ Billion)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74d1f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74d1f_row0_col0" class="data row0 col0" >JPMorgan Chase</td>
#       <td id="T_74d1f_row0_col1" class="data row0 col1" >390.934000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74d1f_row1_col0" class="data row1 col0" >Industrial and Commercial Bank of China</td>
#       <td id="T_74d1f_row1_col1" class="data row1 col1" >345.214000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74d1f_row2_col0" class="data row2 col0" >Bank of America</td>
#       <td id="T_74d1f_row2_col1" class="data row2 col1" >325.331000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74d1f_row3_col0" class="data row3 col0" >Wells Fargo</td>
#       <td id="T_74d1f_row3_col1" class="data row3 col1" >308.013000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74d1f_row4_col0" class="data row4 col0" >China Construction Bank</td>
#       <td id="T_74d1f_row4_col1" class="data row4 col1" >257.399000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74d1f_row5_col0" class="data row5 col0" >HSBC Holdings PLC</td>
#       <td id="T_74d1f_row5_col1" class="data row5 col1" >219.270000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_74d1f_row6_col0" class="data row6 col0" >Agricultural Bank of China</td>
#       <td id="T_74d1f_row6_col1" class="data row6 col1" >203.244000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_74d1f_row7_col0" class="data row7 col0" >Citigroup Inc.</td>
#       <td id="T_74d1f_row7_col1" class="data row7 col1" >203.165000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_74d1f_row8_col0" class="data row8 col0" >Bank of China</td>
#       <td id="T_74d1f_row8_col1" class="data row8 col1" >181.469000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_74d1f_row9_col0" class="data row9 col0" >China Merchants Bank</td>
#       <td id="T_74d1f_row9_col1" class="data row9 col1" >122.616000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_74d1f_row10_col0" class="data row10 col0" >Royal Bank of Canada</td>
#       <td id="T_74d1f_row10_col1" class="data row10 col1" >122.564000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_74d1f_row11_col0" class="data row11 col0" >Banco Santander</td>
#       <td id="T_74d1f_row11_col1" class="data row11 col1" >115.696000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_74d1f_row12_col0" class="data row12 col0" >Commonwealth Bank</td>
#       <td id="T_74d1f_row12_col1" class="data row12 col1" >112.227000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_74d1f_row13_col0" class="data row13 col0" >Mitsubishi UFJ Financial Group</td>
#       <td id="T_74d1f_row13_col1" class="data row13 col1" >111.660000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_74d1f_row14_col0" class="data row14 col0" >Toronto-Dominion Bank</td>
#       <td id="T_74d1f_row14_col1" class="data row14 col1" >108.449000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_74d1f_row15_col0" class="data row15 col0" >BNP Paribas</td>
#       <td id="T_74d1f_row15_col1" class="data row15 col1" >103.258000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_74d1f_row16_col0" class="data row16 col0" >Goldman Sachs</td>
#       <td id="T_74d1f_row16_col1" class="data row16 col1" >100.705000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_74d1f_row17_col0" class="data row17 col0" >Sberbank of Russia</td>
#       <td id="T_74d1f_row17_col1" class="data row17 col1" >99.840000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_74d1f_row18_col0" class="data row18 col0" >Morgan Stanley</td>
#       <td id="T_74d1f_row18_col1" class="data row18 col1" >99.651000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_74d1f_row19_col0" class="data row19 col0" >U.S. Bancorp</td>
#       <td id="T_74d1f_row19_col1" class="data row19 col1" >94.558000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_74d1f_row20_col0" class="data row20 col0" >HDFC Bank</td>
#       <td id="T_74d1f_row20_col1" class="data row20 col1" >88.435000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_74d1f_row21_col0" class="data row21 col0" >Itaú Unibanco</td>
#       <td id="T_74d1f_row21_col1" class="data row21 col1" >86.203000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_74d1f_row22_col0" class="data row22 col0" >Westpac</td>
#       <td id="T_74d1f_row22_col1" class="data row22 col1" >84.560000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_74d1f_row23_col0" class="data row23 col0" >Scotiabank</td>
#       <td id="T_74d1f_row23_col1" class="data row23 col1" >78.947000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_74d1f_row24_col0" class="data row24 col0" >ING Group</td>
#       <td id="T_74d1f_row24_col1" class="data row24 col1" >78.920000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_74d1f_row25_col0" class="data row25 col0" >UBS</td>
#       <td id="T_74d1f_row25_col1" class="data row25 col1" >75.482000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_74d1f_row26_col0" class="data row26 col0" >Charles Schwab</td>
#       <td id="T_74d1f_row26_col1" class="data row26 col1" >74.255000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_74d1f_row27_col0" class="data row27 col0" >PNC Financial Services</td>
#       <td id="T_74d1f_row27_col1" class="data row27 col1" >72.246000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_74d1f_row28_col0" class="data row28 col0" >Lloyds Banking Group</td>
#       <td id="T_74d1f_row28_col1" class="data row28 col1" >71.253000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_74d1f_row29_col0" class="data row29 col0" >Sumitomo Mitsui Financial Group</td>
#       <td id="T_74d1f_row29_col1" class="data row29 col1" >67.328000</td>
#     </tr>
#     <tr>
#       <th id="T_74d1f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_74d1f_row30_col0" class="data row30 col0" >Ba

# %% [markdown]
# <b>Question 1</b> Load the file <code>exchange_rates.csv</code> as a dataframe and find the exchange rate for British pounds with the symbol <code>GBP</code>, store it in the variable  <code>exchange_rate</code>, you will be asked for the number. Hint: set the parameter  <code>index_col</code> to 0.

# %%
def extract_from_csv(file_to_process):
    dataframe = pd.read_csv(file_to_process)
    return dataframe
dataframe = extract_from_csv("exchange_rates.csv")
dataframe = pd.DataFrame(dataframe,columns=['Unnamed: 0','Rates'])
print(dataframe)

i=dataframe[dataframe['Unnamed: 0']=='GBP']
print(i)
exchange_rate = dataframe.iloc[9,1]
print(exchange_rate)
# Out:
#    Unnamed: 0         Rates
# 0         AUD      1.297088
# 1         BGN      1.608653
# 2         BRL      5.409196
# 3         CAD      1.271426
# 4         CHF      0.886083
# 5         CNY      6.483139
# 6         CZK     21.510117
# 7         DKK      6.119757
# 8         EUR      0.822504
# 9         GBP      0.732398
# 10        HKD      7.752509
# 11        HRK      6.222652
# 12        HUF    294.135549
# 13        IDR  14097.902616
# 14        ILS      3.281132
# 15        INR     73.011186
# 16        ISK    129.133081
# 17        JPY    103.791742
# 18        KRW   1105.839776
# 19        MXN     19.932966
# 20        MYR      4.043017
# 21        NOK      8.497121
# 22        NZD      1.393733
# 23        PHP     48.070406
# 24        PLN      3.732933
# 25        RON      4.008883
# 26        RUB     74.930827
# 27        SEK      8.292071
# 28        SGD      1.328261
# 29        THB     30.009870
# 30        TRY      7.418572
# 31        USD      1.000000
# 32        ZAR     15.118441
#   Unnamed: 0     Rates
# 9        GBP  0.732398
# 0.7323984208000001

# %% [markdown]
# ## Transform
#
# Using <code>exchange_rate</code> and the `exchange_rates.csv` file find the exchange rate of USD to GBP. Write a transform function that
#
# 1.  Changes the `Market Cap (US$ Billion)` column from USD to GBP
# 2.  Rounds the Market Cap (US$ Billion)\` column to 3 decimal places
# 3.  Rename `Market Cap (US$ Billion)` to `Market Cap (GBP$ Billion)`

# %%
def extract_from_json(file_to_process):
    df = pd.read_json(file_to_process)
    return df
df=extract_from_json('bank_market_cap_1.json')
df = df.rename(columns={'Market Cap (US$ Billion)': 'Market Cap (GBP$ Billion)'})
def transform(file_to_process):
    return file_to_process*0.73239842
df['Market Cap (GBP$ Billion)'] = df['Market Cap (GBP$ Billion)'].apply(transform)
df=df.round({'Market Cap (GBP$ Billion)': 3})
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_efc23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efc23_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_efc23_level0_col1" class="col_heading level0 col1" >Market Cap (GBP$ Billion)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efc23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efc23_row0_col0" class="data row0 col0" >JPMorgan Chase</td>
#       <td id="T_efc23_row0_col1" class="data row0 col1" >286.319000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efc23_row1_col0" class="data row1 col0" >Industrial and Commercial Bank of China</td>
#       <td id="T_efc23_row1_col1" class="data row1 col1" >252.834000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efc23_row2_col0" class="data row2 col0" >Bank of America</td>
#       <td id="T_efc23_row2_col1" class="data row2 col1" >238.272000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efc23_row3_col0" class="data row3 col0" >Wells Fargo</td>
#       <td id="T_efc23_row3_col1" class="data row3 col1" >225.588000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efc23_row4_col0" class="data row4 col0" >China Construction Bank</td>
#       <td id="T_efc23_row4_col1" class="data row4 col1" >188.519000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_efc23_row5_col0" class="data row5 col0" >HSBC Holdings PLC</td>
#       <td id="T_efc23_row5_col1" class="data row5 col1" >160.593000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_efc23_row6_col0" class="data row6 col0" >Agricultural Bank of China</td>
#       <td id="T_efc23_row6_col1" class="data row6 col1" >148.856000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_efc23_row7_col0" class="data row7 col0" >Citigroup Inc.</td>
#       <td id="T_efc23_row7_col1" class="data row7 col1" >148.798000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_efc23_row8_col0" class="data row8 col0" >Bank of China</td>
#       <td id="T_efc23_row8_col1" class="data row8 col1" >132.908000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_efc23_row9_col0" class="data row9 col0" >China Merchants Bank</td>
#       <td id="T_efc23_row9_col1" class="data row9 col1" >89.804000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_efc23_row10_col0" class="data row10 col0" >Royal Bank of Canada</td>
#       <td id="T_efc23_row10_col1" class="data row10 col1" >89.766000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_efc23_row11_col0" class="data row11 col0" >Banco Santander</td>
#       <td id="T_efc23_row11_col1" class="data row11 col1" >84.736000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_efc23_row12_col0" class="data row12 col0" >Commonwealth Bank</td>
#       <td id="T_efc23_row12_col1" class="data row12 col1" >82.195000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_efc23_row13_col0" class="data row13 col0" >Mitsubishi UFJ Financial Group</td>
#       <td id="T_efc23_row13_col1" class="data row13 col1" >81.780000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_efc23_row14_col0" class="data row14 col0" >Toronto-Dominion Bank</td>
#       <td id="T_efc23_row14_col1" class="data row14 col1" >79.428000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_efc23_row15_col0" class="data row15 col0" >BNP Paribas</td>
#       <td id="T_efc23_row15_col1" class="data row15 col1" >75.626000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_efc23_row16_col0" class="data row16 col0" >Goldman Sachs</td>
#       <td id="T_efc23_row16_col1" class="data row16 col1" >73.756000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_efc23_row17_col0" class="data row17 col0" >Sberbank of Russia</td>
#       <td id="T_efc23_row17_col1" class="data row17 col1" >73.123000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_efc23_row18_col0" class="data row18 col0" >Morgan Stanley</td>
#       <td id="T_efc23_row18_col1" class="data row18 col1" >72.984000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_efc23_row19_col0" class="data row19 col0" >U.S. Bancorp</td>
#       <td id="T_efc23_row19_col1" class="data row19 col1" >69.254000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_efc23_row20_col0" class="data row20 col0" >HDFC Bank</td>
#       <td id="T_efc23_row20_col1" class="data row20 col1" >64.770000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_efc23_row21_col0" class="data row21 col0" >Itaú Unibanco</td>
#       <td id="T_efc23_row21_col1" class="data row21 col1" >63.135000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_efc23_row22_col0" class="data row22 col0" >Westpac</td>
#       <td id="T_efc23_row22_col1" class="data row22 col1" >61.932000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_efc23_row23_col0" class="data row23 col0" >Scotiabank</td>
#       <td id="T_efc23_row23_col1" class="data row23 col1" >57.821000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_efc23_row24_col0" class="data row24 col0" >ING Group</td>
#       <td id="T_efc23_row24_col1" class="data row24 col1" >57.801000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_efc23_row25_col0" class="data row25 col0" >UBS</td>
#       <td id="T_efc23_row25_col1" class="data row25 col1" >55.283000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_efc23_row26_col0" class="data row26 col0" >Charles Schwab</td>
#       <td id="T_efc23_row26_col1" class="data row26 col1" >54.384000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_efc23_row27_col0" class="data row27 col0" >PNC Financial Services</td>
#       <td id="T_efc23_row27_col1" class="data row27 col1" >52.913000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_efc23_row28_col0" class="data row28 col0" >Lloyds Banking Group</td>
#       <td id="T_efc23_row28_col1" class="data row28 col1" >52.186000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_efc23_row29_col0" class="data row29 col0" >Sumitomo Mitsui Financial Group</td>
#       <td id="T_efc23_row29_col1" class="data row29 col1" >49.311000</td>
#     </tr>
#     <tr>
#       <th id="T_efc23_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_efc23_row30_col0" class="data row30 col0" >Bank of C

# %% [markdown]
# ## Load
#
# Create a function that takes a dataframe and load it to a csv named `bank_market_cap_gbp.csv`. Make sure to set `index` to `False`.

# %%
df.to_csv("bank_market_cap_gbp.csv", index=False)

def extract_from_csv(file_to_process):
    dfgbp = pd.read_csv(file_to_process)
    return dfgbp
dfgbp=extract_from_csv('bank_market_cap_gbp.csv')
dfgbp.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_19d9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19d9a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_19d9a_level0_col1" class="col_heading level0 col1" >Market Cap (GBP$ Billion)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19d9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19d9a_row0_col0" class="data row0 col0" >JPMorgan Chase</td>
#       <td id="T_19d9a_row0_col1" class="data row0 col1" >286.319000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19d9a_row1_col0" class="data row1 col0" >Industrial and Commercial Bank of China</td>
#       <td id="T_19d9a_row1_col1" class="data row1 col1" >252.834000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19d9a_row2_col0" class="data row2 col0" >Bank of America</td>
#       <td id="T_19d9a_row2_col1" class="data row2 col1" >238.272000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19d9a_row3_col0" class="data row3 col0" >Wells Fargo</td>
#       <td id="T_19d9a_row3_col1" class="data row3 col1" >225.588000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19d9a_row4_col0" class="data row4 col0" >China Construction Bank</td>
#       <td id="T_19d9a_row4_col1" class="data row4 col1" >188.519000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19d9a_row5_col0" class="data row5 col0" >HSBC Holdings PLC</td>
#       <td id="T_19d9a_row5_col1" class="data row5 col1" >160.593000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19d9a_row6_col0" class="data row6 col0" >Agricultural Bank of China</td>
#       <td id="T_19d9a_row6_col1" class="data row6 col1" >148.856000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_19d9a_row7_col0" class="data row7 col0" >Citigroup Inc.</td>
#       <td id="T_19d9a_row7_col1" class="data row7 col1" >148.798000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_19d9a_row8_col0" class="data row8 col0" >Bank of China</td>
#       <td id="T_19d9a_row8_col1" class="data row8 col1" >132.908000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_19d9a_row9_col0" class="data row9 col0" >China Merchants Bank</td>
#       <td id="T_19d9a_row9_col1" class="data row9 col1" >89.804000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_19d9a_row10_col0" class="data row10 col0" >Royal Bank of Canada</td>
#       <td id="T_19d9a_row10_col1" class="data row10 col1" >89.766000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_19d9a_row11_col0" class="data row11 col0" >Banco Santander</td>
#       <td id="T_19d9a_row11_col1" class="data row11 col1" >84.736000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_19d9a_row12_col0" class="data row12 col0" >Commonwealth Bank</td>
#       <td id="T_19d9a_row12_col1" class="data row12 col1" >82.195000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_19d9a_row13_col0" class="data row13 col0" >Mitsubishi UFJ Financial Group</td>
#       <td id="T_19d9a_row13_col1" class="data row13 col1" >81.780000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_19d9a_row14_col0" class="data row14 col0" >Toronto-Dominion Bank</td>
#       <td id="T_19d9a_row14_col1" class="data row14 col1" >79.428000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_19d9a_row15_col0" class="data row15 col0" >BNP Paribas</td>
#       <td id="T_19d9a_row15_col1" class="data row15 col1" >75.626000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_19d9a_row16_col0" class="data row16 col0" >Goldman Sachs</td>
#       <td id="T_19d9a_row16_col1" class="data row16 col1" >73.756000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_19d9a_row17_col0" class="data row17 col0" >Sberbank of Russia</td>
#       <td id="T_19d9a_row17_col1" class="data row17 col1" >73.123000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_19d9a_row18_col0" class="data row18 col0" >Morgan Stanley</td>
#       <td id="T_19d9a_row18_col1" class="data row18 col1" >72.984000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_19d9a_row19_col0" class="data row19 col0" >U.S. Bancorp</td>
#       <td id="T_19d9a_row19_col1" class="data row19 col1" >69.254000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_19d9a_row20_col0" class="data row20 col0" >HDFC Bank</td>
#       <td id="T_19d9a_row20_col1" class="data row20 col1" >64.770000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_19d9a_row21_col0" class="data row21 col0" >Itaú Unibanco</td>
#       <td id="T_19d9a_row21_col1" class="data row21 col1" >63.135000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_19d9a_row22_col0" class="data row22 col0" >Westpac</td>
#       <td id="T_19d9a_row22_col1" class="data row22 col1" >61.932000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_19d9a_row23_col0" class="data row23 col0" >Scotiabank</td>
#       <td id="T_19d9a_row23_col1" class="data row23 col1" >57.821000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_19d9a_row24_col0" class="data row24 col0" >ING Group</td>
#       <td id="T_19d9a_row24_col1" class="data row24 col1" >57.801000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_19d9a_row25_col0" class="data row25 col0" >UBS</td>
#       <td id="T_19d9a_row25_col1" class="data row25 col1" >55.283000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_19d9a_row26_col0" class="data row26 col0" >Charles Schwab</td>
#       <td id="T_19d9a_row26_col1" class="data row26 col1" >54.384000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_19d9a_row27_col0" class="data row27 col0" >PNC Financial Services</td>
#       <td id="T_19d9a_row27_col1" class="data row27 col1" >52.913000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_19d9a_row28_col0" class="data row28 col0" >Lloyds Banking Group</td>
#       <td id="T_19d9a_row28_col1" class="data row28 col1" >52.186000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_19d9a_row29_col0" class="data row29 col0" >Sumitomo Mitsui Financial Group</td>
#       <td id="T_19d9a_row29_col1" class="data row29 col1" >49.311000</td>
#     </tr>
#     <tr>
#       <th id="T_19d9a_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_19d9a_row30_col0" class="data row30 col0" >Bank of C

# %% [markdown]
# ## Logging Function

# %% [markdown]
# Write the logging function <code>log</code> to log your data:

# %%
def log(message):
    timestamp_format = '%Y-%h-%d-%H:%M-%S'
    now = datetime.now()
    timestamp = now.strftime(timestamp_format)
    with open ("logfile.txt","a") as f:
        f.write (timestamp + ',' + message +'/n')

# %% [markdown]
# ## Running the ETL Process

# %% [markdown]
# Log the process accordingly using the following <code>"ETL Job Started"</code> and <code>"Extract phase Started"</code>

# %%
# Write your code here
log ("ETL Job Started")
log ("Extract phase Started")

# %% [markdown]
# ### Extract

# %% [markdown]
# <code>Question 2</code> Use the function <code>extract</code>, and print the first 5 rows, take a screen shot:

# %%
# Call the function here
df=extract_from_json('bank_market_cap_1.json')

# Print the rows here
df.head
# Out:
# <bound method NDFrame.head of                                        Name  Market Cap (US$ Billion)
# 0                            JPMorgan Chase                   390.934
# 1   Industrial and Commercial Bank of China                   345.214
# 2                           Bank of America                   325.331
# 3                               Wells Fargo                   308.013
# 4                   China Construction Bank                   257.399
# ..                                      ...                       ...
# 65                             Ping An Bank                    37.993
# 66                       Standard Chartered                    37.319
# 67                     United Overseas Bank                    35.128
# 68                                QNB Group                    33.560
# 69                              Bank Rakyat                    33.081
#
# [70 rows x 2 columns]>

# %% [markdown]
# Log the data as <code>"Extract phase Ended"</code>

# %%
# Write your code here
log ("Extract phase Ended")

# %% [markdown]
# ### Transform

# %% [markdown]
# Log the following  <code>"Transform phase Started"</code>

# %%
# Write your code here
log ("Transform phase Started")

# %% [markdown]
# <code>Question 3</code> Use the function <code>transform</code> and print the first 5 rows of the output, take a screen shot:

# %%
# Call the function here
df = df.rename(columns={'Market Cap (US$ Billion)': 'Market Cap (GBP$ Billion)'})
df['Market Cap (GBP$ Billion)'] = df['Market Cap (GBP$ Billion)'].apply(transform)
df=df.round({'Market Cap (GBP$ Billion)': 3})
# Print the first 5 rows here
df.head
# Out:
# <bound method NDFrame.head of                                        Name  Market Cap (GBP$ Billion)
# 0                            JPMorgan Chase                    286.319
# 1   Industrial and Commercial Bank of China                    252.834
# 2                           Bank of America                    238.272
# 3                               Wells Fargo                    225.588
# 4                   China Construction Bank                    188.519
# ..                                      ...                        ...
# 65                             Ping An Bank                     27.826
# 66                       Standard Chartered                     27.332
# 67                     United Overseas Bank                     25.728
# 68                                QNB Group                     24.579
# 69                              Bank Rakyat                     24.228
#
# [70 rows x 2 columns]>

# %% [markdown]
# Log your data <code>"Transform phase Ended"</code>

# %%
# Write your code here
log ("Transform phase Ended")

# %% [markdown]
# ### Load

# %% [markdown]
# Log the following `"Load phase Started"`.

# %%
# Write your code here
log ("Load phase Started")

# %% [markdown]
# Call the load function

# %%
# Write your code here
df.to_csv("bank_market_cap_gbp.csv", index=False)

# %% [markdown]
# Log the following `"Load phase Ended"`.

# %%
# Write your code here
log ("Load phase Ended")

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santrcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
